# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Jan Cronje__
# Quantitative Programmer

# %% [markdown]
# _I am interested in data science because I nedd a raise_

# %% [markdown]
# ### The following code mulitply 5 by 6

# %%
x = 5
y = 6
product = x * y
print("Product of {} and {} is {}".format(x,y,product))
# Out:
# Product of 5 and 6 is 30

# %% [markdown]
# 1. One
# 2. Two
# ***
# [click me](http://google.com)
#
# - One
# - Two
